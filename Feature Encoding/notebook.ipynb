# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
df= pd.read_csv('Data/Churn_Modelling.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9935 non-null   object
#  6   Age              9929 non-null   float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(columns=["CustomerId","Surname","CustomerId","RowNumber"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.0       2       0.00              1
# 1          608     Spain  Female  41.0       1   83807.86              1
# 2          502    France  Female  42.0       8  159660.80              3
# 3          699    France  Female   NaN       1       0.00              2
# 4          850     Spain  Female  43.0       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(65)

# %% [markdown]
# ### Handling missing values

# %%
df.Gender.mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df['Gender']=df['Gender'].fillna('Male')

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              9929 non-null   float64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 859.5+ KB

# %% [markdown]
# # Label Encoding

# %%
# label encoding
le = preprocessing.LabelEncoder()
df['Gender_lebel_encoded'] = le.fit_transform(df['Gender'])
df.head()
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.0       2       0.00              1
# 1          608     Spain  Female  41.0       1   83807.86              1
# 2          502    France  Female  42.0       8  159660.80              3
# 3          699    France  Female   NaN       1       0.00              2
# 4          850     Spain  Female  43.0       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Gender_lebel_encoded
# 0          1               1        101348.88       1                     0
# 1          0               1        112542.58       0                     0
# 2          1               0        113931.57       1                     0
# 3          0               0         93826.63       0                     0
# 4          1               1         79084.10       0                     0

# %%
df.Gender_lebel_encoded.value_counts()
# Out:
# Gender_lebel_encoded
# 1    5489
# 0    4511
# Name: count, dtype: int64

# %% [markdown]
# # Onehot encoding

# %%
# one hot encoding
one_hot_encoded = pd.get_dummies(df, columns=['Geography'])
one_hot_encoded
# Out:
#       CreditScore  Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619  Female  42.0       2       0.00              1          1
# 1             608  Female  41.0       1   83807.86              1          0
# 2             502  Female  42.0       8  159660.80              3          1
# 3             699  Female   NaN       1       0.00              2          0
# 4             850  Female  43.0       2  125510.82              1          1
# ...           ...     ...   ...     ...        ...            ...        ...
# 9995          771    Male  39.0       5       0.00              2          1
# 9996          516    Male  35.0      10   57369.61              1          1
# 9997          709  Female  36.0       7       0.00              1          0
# 9998          772    Male  42.0       3   75075.31              2          1
# 9999          792  Female  28.0       4  130142.79              1          1
#
# ...

# %%
df.head()
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.0       2       0.00              1
# 1          608     Spain  Female  41.0       1   83807.86              1
# 2          502    France  Female  42.0       8  159660.80              3
# 3          699    France  Female   NaN       1       0.00              2
# 4          850     Spain  Female  43.0       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Gender_lebel_encoded
# 0          1               1        101348.88       1                     0
# 1          0               1        112542.58       0                     0
# 2          1               0        113931.57       1                     0
# 3          0               0         93826.63       0                     0
# 4          1               1         79084.10       0                     0

# %%
df_dummy = pd.get_dummies(df)
df_dummy.head()
# Out:
#    CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619  42.0       2       0.00              1          1
# 1          608  41.0       1   83807.86              1          0
# 2          502  42.0       8  159660.80              3          1
# 3          699   NaN       1       0.00              2          0
# 4          850  43.0       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Gender_lebel_encoded  \
# 0               1        101348.88       1                     0
# 1               1        112542.58       0                     0
# 2               0        113931.57       1                     0
# 3               0         93826.63       0                     0
# 4               1         79084.10       0                     0
#
#    Geography_France  Geography_Germany  Geography_Spain  Gender_Female  \
# 0              True              False            False           True
# ...
